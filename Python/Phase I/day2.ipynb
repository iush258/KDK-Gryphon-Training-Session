# %% [markdown]
# ## Day 2 Gryphon Training
#
# ### Errors and Exception Handling
#
# types of Errors
#
# 1. Semantic Errors
# 2. Syntax Error
# 3. Exception (runtime Error)
#
# semantic error :- Error within the Logic
# Syntax:- Within the syntax of error
# Exception Error :- Error Occured during the Runtime of Program
#
#
# Exception Error Can be Avoided using Try and Except Block
# ```
# try:
#
#     <code>
#
# except:
#
#     <code after the exception is occured>
# ```
#
#
# Types of Exceptions
# 1. ZeroDivisionError
# 2. IndexError
# 3. ValueError
# 4. TypeError
# 5. Keyerror
# 6. FileNotFoundError
#
# We can Mention multiple Exception in Exception block using ,
# Ex:
# ```
#     except(ZeroDivisionError , TypeError , IndexError):
#         print("Error is Handled By Try and Exception")
# ```

# %%
try:
    a = int(input("enter 1st No:"))
    b = int(input("enter 1st No:"))
    c= a/b

except(ZeroDivisionError):
    print("Cannot divide anything using 0")


except(ValueError):
    print("Please Provide Integers only")

#else block gets executed if there is no Exception

else:
    print(c)

# finally blocks gets executed Anyways even when the Exception is occured or not

finally:
    print("Operations are Done Completed")

# Raise is used to throw and Custom Exception to the user
# Out:
# 0.5
# Operations are Done Completed

# %% [markdown]
# ## File Handling
# Acessing and modifying the File Through PRograming is called as File handling
#
# Types of Files:
#
# 1. Text files :- .txt .py .c .java
# 2. binary files :- ppt , images , audios , pdf, videos etc
#
#
# #### File Paths
#
# 1. Absoulute Path
# 2. Relative Path
#
#
# ### Absolute Path
# Absolute path: Is the Path of the File where The path of the file is Mentioned From the Base Directory of the System
#
# EX
# ```/mnt/shared/T&P Session Final Yr/```
#
# ### Relative Path
# Relative Path : Is the path of the File From the current File/folder , This type of file path is preferred as Diff System has diff File Systems and Structures
#
#
# #### Operations Performed on Files
# 1. Read
# 2. Write
# 3. Open
# 4. Close
# 5. Seek
# 6. Append
#
# ##### 1.Read()
# ```fp.read()```
# read the contents of the file and stores in the file pointer
#
# ```fp.read(n)```
# Reads n No of Bytes in a File
#
#
# ```fp.readline()```
# Reads the Content of File Line wise
#
# ```fp.readlines()```
# Reads The lines of the file and returns in List of Strings
#
#
#
# File pointer Moves Forwards by the number of bytes
#
#
# In read Mode there are 2 cases
# 1. If files already Exists -> it will read the data
# 2. If file does not exists -> it will throws file not found exception
#
#
#
# ##### 2.Write()
#
# 1. ``fp.write``
# This write into the file opened in file pointer fp.
# The if the file does not exists it will create one.
# The text gets overwrites!!!!!.
#
#
# 2. ```fp.writelines```  But fp.writeline does not exists in python because write function is used to write lines
#
# 3. ```fp.writelines``` it takes multiple lines in Form of List to write in File, oposite of writelines
#
#
# #### 3. Append()
#
# Write The Text at the End of the Files
#
# `fp.write()
# ` it is also done in write function due to the file pointer
#
# in Read and Write mode File pointer Begins from Begining of file
# whereas in Append mode the file pointer At the End of the File
#
#
#
#  File Context :
#  opening file with with statements this automatically closes the file pointer
#
#  ex:
#  ``` with open ("<filename>,<filemode>") as fp ```
#
# ###### Assignments
#  WAP TO COUNT NO OF CHAR , NO OF LINES and NO OF WORDS

# %%
# readiing in File
with open ('trialfile.txt', 'r') as f1:

    a=f1.read()
    print(a)

    b=f1.read(2)
    print(b)

    c=f1.readline()
    print(c)

    d=f1.readlines()
    print(d)
# Out:
# hello Negga
# helo lolol
#
#
# []

# %%
# wrting the File
with open ('trialfile.txt', 'r') as f1:
    f1.write("hello Negga")

# %%
with open ("trialfile.txt","r")as fp:
    with open("trailfile2.txt","w")as fp2:
        a=fp.read()
        fp2.write(a)
